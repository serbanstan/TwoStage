# %% [markdown]
# ### in this set of experiments, we are given a completed ratings matrix

# %%
import numpy as np
import math
import time
import matplotlib.pyplot as plt
import random

from scipy import stats

# %%
ratingsFile = open("ratingsSummary.csv", "r")

userRatings = dict()
relevantMovies = dict()

for line in ratingsFile:
    data = map(float,line.split(','))
    
    usr = int(data[0])
    mov = int(data[1])
    r = int(data[2])
    
    if usr in userRatings:
        userRatings[usr][mov] = r
    else:
        userRatings[usr] = dict()
        userRatings[usr][mov] = r
        
    relevantMovies[mov] = True
    
print len(userRatings.keys()), len(relevantMovies.keys())
# Out:
# 200 1995

# %% [markdown]
# ### Now, read in the movies.

# %%
movies = dict() # a category -> list_of_movies dict stored as integers
movieCats = dict() # movieID -> categories movie is part

# catID returns the index of a category of type string. catName returns the name of the category given its ID.
catID = dict()
catName = dict()

# same as with cat
movieID = dict()
movieName = dict()

# %%
allData = open("movies.csv", "r")

# this first line contains header info
allData.readline()

numMovies = 0
numGenres = 0

while True:
    line = allData.readline()
    
    if line == '':
        break
    
    curMovieID = int(line.split(",", 1)[0])
    if curMovieID not in relevantMovies.keys():
        continue
    
    curMovieName = (line.split(",", 1)[1]).rsplit(",", 1)[0]
    curCategories = line.rsplit(",", 1)[1].rsplit("\r")[0].split("|")
    
    
    # update catID, catName, movieID, movieName
    movieID[curMovieName] = curMovieID
    movieName[curMovieID] = curMovieName
    
    for cat in curCategories:
        if not (cat in catID):
            catID[cat] = numGenres
            catName[numGenres] = cat
            
            numGenres = numGenres + 1
            
    movieCats[curMovieID] = curCategories
            
    for cat in curCategories:
        if catID[cat] in movies:
            movies[catID[cat]].append(movieID[curMovieName])
        else:
            movies[catID[cat]] = [movieID[curMovieName]]
    
    numMovies = numMovies + 1

print "we have", numMovies, "movies"
# Out:
# we have 1995 movies

# %%
print movies[catID['Horror']][:10]
print movieName[movies[catID['Horror']][0]]
print movieCats[movies[catID['Horror']][0]]
print catID.keys()
# Out:
# [593, 1076, 1200, 1214, 1219, 1258, 1261, 1333, 1340, 1348]
# "Silence of the Lambs, The (1991)"
# ['Crime', 'Horror', 'Thriller']
# ['Mystery', 'Romance', 'Sci-Fi', 'Musical', 'Film-Noir', 'Crime', 'Drama', 'Fantasy', 'Western', 'Animation', 'War', 'Adventure', 'Horror', 'Action', '(no genres listed)', 'Comedy', 'Documentary', 'Children', 'Thriller', 'IMAX']

# %%
print 'We have', len(userRatings.keys()), 'users'
print 'We have', len(movieCats), 'movies'
print 'We have', len(catID.keys()), 'genres'
# Out:
# We have 200 users
# We have 1995 movies
# We have 20 genres

# %%
numMovies = len(movieCats)
numUsers = len(userRatings.keys())

print numMovies, numUsers
# Out:
# 1995 200

# %% [markdown]
# ### Now, complete the ratings matrix

# %%
ratingsIncomplete = np.array([[float('NaN') for i in range(numMovies)] for j in range(numUsers)])

movieList = movieName.keys()
userList = userRatings.keys()

for user in userRatings:
    for mov in userRatings[user]:
        line = userList.index(user)
        col = movieList.index(mov)
        
        ratingsIncomplete[line][col] = userRatings[user][mov]

# %%
from fancyimpute import SoftImpute

startTime = time.time()

solver = SoftImpute(
    min_value=0.0,
    max_value=5.0)

ratingsComplete = solver.complete(ratingsIncomplete)

print time.time() - startTime
# Out:
# Using TensorFlow backend.
# [SoftImpute] Max Singular Value of X_init = 1123.683327
# [SoftImpute] Iter 1: observed MAE=0.522688 rank=196
# [SoftImpute] Iter 2: observed MAE=0.537585 rank=193
# [SoftImpute] Iter 3: observed MAE=0.548181 rank=177
# [SoftImpute] Iter 4: observed MAE=0.548157 rank=153
# [SoftImpute] Iter 5: observed MAE=0.544339 rank=134
# [SoftImpute] Iter 6: observed MAE=0.539971 rank=116
# [SoftImpute] Iter 7: observed MAE=0.535780 rank=104
# [SoftImpute] Iter 8: observed MAE=0.532160 rank=93
# [SoftImpute] Iter 9: observed MAE=0.528867 rank=85
# [SoftImpute] Iter 10: observed MAE=0.526145 rank=78
# [SoftImpute] Iter 11: observed MAE=0.523777 rank=74
# [SoftImpute] Iter 12: observed MAE=0.521712 rank=71
# [SoftImpute] Iter 13: observed MAE=0.519792 rank=68
# [SoftImpute] Iter 14: observed MAE=0.518061 rank=65
# [SoftImpute] Iter 15: observed MAE=0.516570 rank=62
# [SoftImpute] Iter 16: observed MAE=0.515245 rank=61
# [SoftImpute] Iter 17: observed MAE=0.514135 rank=61
# [SoftImpute] Iter 18: observed MAE=0.513141 rank=60
# [SoftImpute] Iter 19: observed MAE=0.512242 rank=58
# [SoftImpute] Iter 20: observed MAE=0.511421 rank=57
# [SoftImpute] Iter 21: observed MAE=0.510680 rank=57
# [SoftImpute] Iter 22: observed MAE=0.509994 rank=56
# [SoftImpute] Iter 23: observed MAE=0.509379 rank=56
# [SoftImpute] Iter 24: observed MAE=0.508823 rank=56
# [SoftImpute] Iter 25: observed MAE=0.508311 rank=56
# [SoftImpute] Iter 26: observed MAE=0.507826 rank=55
# [SoftImpute] Iter 27: observed MAE=0.507356 rank=55
# [SoftImpute] Iter 28: observed MAE=0.506916 rank=54
# [SoftImpute] Iter 29: observed MAE=0.506502 rank=54
# [SoftImpute] Iter 30: observed MAE=0.506122 rank=54
# [SoftImpute] Iter 31: observed MAE=0.505775 rank=54
# [SoftImpute] Iter 32: observed MAE=0.505456 rank=53
# [SoftImpute] Iter 33: observed MAE=0.505157 rank=53
# [SoftImpute] Iter 34: observed MAE=0.504882 rank=53
# [SoftImpute] Iter 35: observed MAE=0.504629 rank=53
# [SoftImpute] Iter 36: observed MAE=0.504391 rank=53
# [SoftImpute] Iter 37: observed MAE=0.504169 rank=53
# [SoftImpute] Iter 38: observed MAE=0.503962 rank=53
# [SoftImpute] Iter 39: observed MAE=0.503767 rank=53
# [SoftImpute] Iter 40: observed MAE=0.503580 rank=53
# [SoftImpute] Iter 41: observed MAE=0.503403 rank=53
# [SoftImpute] Iter 42: observed MAE=0.503234 rank=53
# [SoftImpute] Iter 43: observed MAE=0.503070 rank=53
# [SoftImpute] Iter 44: observed MAE=0.502914 rank=53
# [SoftImpute] Iter 45: observed MAE=0.502765 rank=53
# [SoftImpute] Iter 46: observed MAE=0.502623 rank=53
# [SoftImpute] Iter 47: observed MAE=0.502489 rank=53
# [SoftImpute] Iter 48: observed MAE=0.502361 rank=53
# [SoftImpute] Iter 49: observed MAE=0.502238 rank=53
# [SoftImpute] Iter 50: observed MAE=0.502122 rank=53
# [SoftImpute] Iter 51: observed MAE=0.502010 rank=53
# [SoftImpute] Iter 52: observed MAE=0.501904 rank=53
# [SoftImpute] Iter 53: observed MAE=0.501803 rank=53
# [SoftImpute] Iter 54: observed MAE=0.501707 rank=53
# [SoftImpute] Iter 55: observed MAE=0.501616 rank=53
# [SoftImpute] Iter 56: observed MAE=0.501529 rank=53
# [SoftImpute] Iter 57: observed MAE=0.501446 rank=53
# [SoftImpute] Iter 58: observed MAE=0.501367 rank=53
# [SoftImpute] Iter 59: observed MAE=0.501293 rank=53
# [SoftImpute] Iter 60: observed MAE=0.501222 rank=53
# [SoftImpute] Iter 61: observed MAE=0.501155 rank=53
# [SoftImpute] Iter 62: observed MAE=0.501090 rank=52
# [SoftImpute] Iter 63: observed MAE=0.501029 rank=52
# [SoftImpute] Iter 64: observed MAE=0.500970 rank=52
# [SoftImpute] Iter 65: observed MAE=0.500915 rank=52
# [SoftImpute] Iter 66: observed MAE=0.500863 rank=52
# [SoftImpute] Iter 67: observed MAE=0.500813 rank=52
# [SoftImpute] Iter 68: observed MAE=0.500766 rank=52
# [SoftImpute] Iter 69: observed MAE=0.500722 rank=52
# [SoftImpute] Iter 70: observed MAE=0.500679 rank=52
# [SoftImpute] Iter 71: observed MAE=0.500639 rank=52
# [SoftImpute] Iter 72: observed MAE=0.500601 rank=52
# [SoftImpute] Iter 73: observed MAE=0.500565 rank=52
# [SoftImpute] Iter 74: observed MAE=0.500530 rank=52
# [SoftImpute] Iter 75: observed MAE=0.500498 rank=52
# [SoftImpute] Iter 76: observed MAE=0.500466 rank=52
# [SoftImpute] Iter 77: observed MAE=0.500437 rank=52
# [SoftImpute] Iter 78: observed MAE=0.500408 rank=52
# [SoftImpute] Iter 79: observed MAE=0.500381 rank=52
# [SoftImpute] Stopped after iteration 79 for lambda=22.473667
# 6.68817591667

# %%
# now, update the remaining ratings
for user in userList:
    for mov in movieList:
        line = userList.index(user)
        col = movieList.index(mov)
        
        if mov in userRatings[user]:
            assert userRatings[user][mov] == ratingsComplete[line][col], \
            "The initial ratings and completed rating should be equal"
        
        userRatings[user][mov] = ratingsComplete[line][col]

# %% [markdown]
# ### at this point in time, we should be in the setting from exp_1, but with the filled up ratings matrix

# %%
k = 3

# %%
from replacementGreedy import replacementGreedy
from greedysum import gsWrapper
from greedymerge import gmWrapper

# %%
def computeCostOuter(userIndex, A):
    tot = 0

    curUser = userRatings.keys()[userIndex]

    catA = dict()
    for cat in catID.keys():
        catA[cat] = []
    for mov in A:
        for cat in movieCats[mov]:
            catA[cat].append(mov)

    for cat in catID.keys():
        # now, find the highest rated movie in each category
        highestRated = 0
        for mov in catA[cat]:
            highestRated = max(highestRated, userRatings[curUser][mov])

        tot = tot + highestRated

    return tot

# compute the greedy maximization solution for S for the second stage submodular maximization
def greedyOuter(userIndex, S):
    greedyS = []

    use = [False for s in S]

    for times in range(k):
        # at each step, add the element that gives the greatest marginal gain 

        bestInd = -1
        bestCost = -1

        for ind in range(len(S)):
            if use[ind] == False:
                greedyS.append(S[ind])

                curCost = computeCostOuter(userIndex, greedyS)
                if curCost > bestCost:
                    bestCost = curCost
                    bestInd = ind

                greedyS.pop()

        greedyS.append(S[bestInd])
        use[bestInd] = True

    return computeCostOuter(userIndex, greedyS)

# return the mean, the confidence interval, and the runtime to compute
def computeRatio(S, otherUsers):
    groundSetMean = 0
    for other in otherUsers:
        groundSetMean = groundSetMean + greedyOuter(other, movieName.keys())
    groundSetMean = 1.0 * groundSetMean / len(otherUsers)

    rtS = time.time()
    Sval = []
    for other in otherUsers:
        curVal = greedyOuter(other, S) / groundSetMean
        Sval.append(curVal)
    rtS = time.time() - rtS
    
    print np.mean(Sval)
    
    return np.mean(Sval), \
        stats.norm.interval(0.95, loc=np.mean(Sval), scale=np.std(Sval)/np.sqrt(len(otherUsers))), \
        rtS

# %%
#set l
l = 60

rg = replacementGreedy(numMovies, numUsers/2, l, k, \
                            userRatings, movieCats, catID.keys())
rgSs, rgCosts, rgEvals, rgTimes = rg(movieName.keys())

print ''
gs = gsWrapper(numMovies, numUsers/2, l, k, userRatings, movieCats, catID.keys())
gsSs, gsCosts, gsEvals, gsTimes = gs(movieName.keys())

print ''
gm = gmWrapper(numMovies, numUsers/2, l, k, userRatings, movieCats, catID.keys())
gmS, gmCost, gmEvals, gmTime = gm(movieName.keys())

# also, generate a set of random movies, to test the ratios we get against it
randS = random.sample(movieName.keys(), l)
# Out:
# Finished step  2  with cost  5022.77128846 ; number of evals 1198297 ; total runtime 32.9475159645
# Finished step  3  with cost  5218.4157217 ; number of evals 2016984 ; total runtime 64.9681239128
# Finished step  4  with cost  5361.4479926 ; number of evals 2835488 ; total runtime 94.6756770611
# Finished step  5  with cost  5440.04908167 ; number of evals 3640912 ; total runtime 122.418670893
# Finished step  6  with cost  5495.30087278 ; number of evals 4445952 ; total runtime 153.39180994
# Finished step  7  with cost  5539.53903961 ; number of evals 5249504 ; total runtime 182.200067997
# Finished step  8  with cost  5570.50871255 ; number of evals 6051736 ; total runtime 210.353874922
# Finished step  9  with cost  5618.90085874 ; number of evals 6854128 ; total runtime 239.19709897
# Finished step  10  with cost  5643.74696537 ; number of evals 7655544 ; total runtime 268.164149046
# Finished step  11  with cost  5668.19272857 ; number of evals 8456484 ; total runtime 296.713762045
# Finished step  12  with cost  5691.07110888 ; number of evals 9257516 ; total runtime 324.697144985
# Finished step  13  with cost  5710.51440668 ; number of evals 10057900 ; total runtime 353.917769909
# Finished step  14  with cost  5726.56827817 ; number of evals 10857880 ; total runtime 381.535410881
# Finished step  15  with cost  5741.88752472 ; number of evals 11657836 ; total runtime 411.624891996
# Finished step  16  with cost  5756.4932138 ; number of evals 12457764 ; total runtime 440.67446804
# Finished step  17  with cost  5769.811731 ; number of evals 13257648 ; total runtime 469.166180849
# Finished step  18  with cost  5785.9402226 ; number of evals 14057336 ; total runtime 496.731929064
# Finished step  19  with cost  5799.75153929 ; number of evals 14856880 ; total runtime 524.013157845
# Finished step  20  with cost  5816.97120457 ; number of evals 15656316 ; total runtime 550.725483894
# Finished step  21  with cost  5827.34648286 ; number of evals 16455680 ; total runtime 577.594753027
# Finished step  22  with cost  5835.14235699 ; number of evals 17254848 ; total runtime 608.050895929
# Finished step  23  with cost  5844.98910972 ; number of evals 18053948 ; total runtime 636.103188038
# Finished step  24  with cost  5852.98910972 ; number of evals 18852980 ; total runtime 666.054920912
# Finished step  25  with cost  5860.51295308 ; number of evals 19651968 ; total runtime 695.545798063
# Finished step  26  with cost  5867.16386178 ; number of evals 20450992 ; total runtime 723.875880003
# Finished step  27  with cost  5873.09465139 ; number of evals 21250024 ; total runtime 751.475956917
# Finished step  28  with cost  5878.07127687 ; number of evals 22049076 ; total runtime 779.403032064
# Finished step  29  with cost  5885.5391054 ; number of evals 22848076 ; total runtime 807.150601864
# Finished step  30  with cost  5889.60787018 ; number of evals 23647064 ; total runtime 834.095984936
# Finished step  31  with cost  5893.60787018 ; number of evals 24445992 ; total runtime 861.598722935
# Finished step  32  with cost  5897.60787018 ; number of evals 25244916 ; total runtime 889.860012054
# Finished step  33  with cost  5901.51125142 ; number of evals 26043852 ; total runtime 917.745626926
# Finished step  34  with cost  5905.30647431 ; number of evals 26842708 ; total runtime 945.53443408
# Finished step  35  with cost  5910.30647431 ; number of evals 27641548 ; total runtime 973.450679064
# Finished step  36  with cost  5914.30647431 ; number of evals 28440316 ; total runtime 1000.76392102
# Finished step  37  with cost  5917.30647431 ; number of evals 29239060 ; total runtime 1028.31315303
# Finished step  38  with cost  5920.30647431 ; number of evals 30037800 ; total runtime 1057.732934
# Finished step  39  with cost  5923.30647431 ; number of evals 30836492 ; total runtime 1087.38218784
# Finished step  40  with cost  5927.30647431 ; number of evals 31635180 ; total runtime 1115.79733801
# Finished step  41  with cost  5930.30647431 ; number of evals 32433864 ; total runtime 1146.06173992
# Finished step  42  with cost  5933.03357113 ; number of evals 33232548 ; total runtime 1174.08304286
# Finished step  43  with cost  5935.359432 ; number of evals 34031208 ; total runtime 1202.2132709
# Finished step  44  with cost  5937.359432 ; number of evals 34829860 ; total runtime 1229.63896108
# Finished step  45  with cost  5939.29154307 ; number of evals 35628504 ; total runtime 1257.08750391
# Finished step  46  with cost  5940.88081659 ; number of evals 36427132 ; total runtime 1285.20069385
# Finished step  47  with cost  5942.16658164 ; number of evals 37225756 ; total runtime 1313.01870489
# Finished step  48  with cost  5943.39404011 ; number of evals 38024360 ; total runtime 1340.63786197
# Finished step  49  with cost  5944.47067368 ; number of evals 38822964 ; total runtime 1367.95316291
# Finished step  50  with cost  5945.52164804 ; number of evals 39621572 ; total runtime 1395.33206701
# Finished step  51  with cost  5946.52164804 ; number of evals 40420172 ; total runtime 1422.27616692
# Finished step  52  with cost  5947.52164804 ; number of evals 41218768 ; total runtime 1451.59059691
# Finished step  53  with cost  5948.52164804 ; number of evals 42017360 ; total runtime 1479.16063595
# Finished step  54  with cost  5949.52164804 ; number of evals 42815952 ; total runtime 1507.19065905
# Finished step  55  with cost  5950.52164804 ; number of evals 43614540 ; total runtime 1534.66829896
# Finished step  56  with cost  5951.52164804 ; number of evals 44413120 ; total runtime 1562.65244508
# Finished step  57  with cost  5952.82177515 ; number of evals 45211700 ; total runtime 1591.49561501
# Finished step  58  with cost  5953.82177515 ; number of evals 46010276 ; total runtime 1619.49769402
# Finished step  59  with cost  5954.82177515 ; number of evals 46808848 ; total runtime 1647.2186439
#
# Finished step  2  with cost  5022.77128846 ; number of evals 599200 ; total runtime 16.2965180874
# Finished step  3  with cost  5146.31912052 ; number of evals 799700 ; total runtime 24.0278871059
# Finished step  4  with cost  5266.54121367 ; number of evals 1000500 ; total runtime 32.2885560989
# Finished step  5  with cost  5314.7594974 ; number of evals 1201600 ; total runtime 41.2565910816
# Finished step  6  with cost  5314.7594974 ; number of evals 1403000 ; total runtime 51.3048000336
# Finished step  7  with cost  5375.07403955 ; number of evals 1604700 ; total runtime 61.7136931419
# Finished step  8  with cost  5375.07403955 ; number of evals 1806700 ; total runtime 72.6616711617
# Finished step  9  with cost  5474.2897326 ; number of evals 2009000 ; total runtime 83.5550031662
# Finished step  10  with cost  5506.40229978 ; number of evals 2211600 ; total runtime 95.4387431145
# Finished step  11  with cost  5513.16475672 ; number of evals 2414500 ; total runtime 109.097349167
# Finished step  12  with cost  5515.16475672 ; number of evals 2617700 ; total runtime 123.568694115
# Finished step  13  with cost  5516.69205173 ; number of evals 2821200 ; total runtime 137.471018076
# Finished step  14  with cost  5531.96279708 ; number of evals 3025000 ; total runtime 152.6879251
# Finished step  15  with cost  5532.64979221 ; number of evals 3229100 ; total runtime 168.044487
# Finished step  16  with cost  5532.64979221 ; number of evals 3433500 ; total runtime 183.787129164
# Finished step  17  with cost  5555.09015211 ; number of evals 3638200 ; total runtime 200.659137011
# Finished step  18  with cost  5570.67563415 ; number of evals 3843200 ; total runtime 217.921422005
# Finished step  19  with cost  5588.17497573 ; number of evals 4048500 ; total runtime 236.773203135
# Finished step  20  with cost  5588.17497573 ; number of evals 4254100 ; total runtime 256.61443305
# Finished step  21  with cost  5588.20041558 ; number of evals 4460000 ; total runtime 276.830260992
# Finished step  22  with cost  5588.20041558 ; number of evals 4666200 ; total runtime 297.78442502
# Finished step  23  with cost  5614.21125852 ; number of evals 4872700 ; total runtime 319.344433069
# Finished step  24  with cost  5614.21125852 ; number of evals 5079500 ; total runtime 341.604217052
# Finished step  25  with cost  5613.77810134 ; number of evals 5286600 ; total runtime 363.486417055
# Finished step  26  with cost  5613.77810134 ; number of evals 5494000 ; total runtime 386.300432205
# Finished step  27  with cost  5622.29346313 ; number of evals 5701700 ; total runtime 409.933525085
# Finished step  28  with cost  5622.29346313 ; number of evals 5909700 ; total runtime 434.01531601
# Finished step  29  with cost  5622.29346313 ; number of evals 6118000 ; total runtime 459.391538143
# Finished step  30  with cost  5622.29346313 ; number of evals 6326600 ; total runtime 485.221793175
# Finished step  31  with cost  5627.89797047 ; number of evals 6535500 ; total runtime 511.930184126
# Finished step  32  with cost  5630.89797047 ; number of evals 6744700 ; total runtime 538.971752167
# Finished step  33  with cost  5658.89288133 ; number of evals 6954200 ; total runtime 567.033293009
# Finished step  34  with cost  5658.89288133 ; number of evals 7164000 ; total runtime 595.445372105
# Finished step  35  with cost  5658.89288133 ; number of evals 7374100 ; total runtime 624.103509188
# Finished step  36  with cost  5678.67498083 ; number of evals 7584500 ; total runtime 653.030142069
# Finished step  37  with cost  5678.67498083 ; number of evals 7795200 ; total runtime 682.980190992
# Finished step  38  with cost  5678.67498083 ; number of evals 8006200 ; total runtime 717.353214025
# Finished step  39  with cost  5678.67498083 ; number of evals 8217500 ; total runtime 748.725675106
# Finished step  40  with cost  5678.67498083 ; number of evals 8429100 ; total runtime 780.012708187
# Finished step  41  with cost  5692.96175882 ; number of evals 8641000 ; total runtime 814.771119118
# Finished step  42  with cost  5692.96175882 ; number of evals 8853200 ; total runtime 848.070468187
# Finished step  43  with cost  5692.96175882 ; number of evals 9065700 ; total runtime 881.634581089
# Finished step  44  with cost  5692.96175882 ; number of evals 9278500 ; total runtime 914.71550107
# Finished step  45  with cost  5695.84959675 ; number of evals 9491600 ; total runtime 948.825086117
# Finished step  46  with cost  5695.84959675 ; number of evals 9705000 ; total runtime 983.308888197
# Finished step  47  with cost  5695.84959675 ; number of evals 9918700 ; total runtime 1019.02164602
# Finished step  48  with cost  5700.09067826 ; number of evals 10132700 ; total runtime 1054.05023503
# Finished step  49  with cost  5700.09067826 ; number of evals 10347000 ; total runtime 1090.46932817
# Finished step  50  with cost  5705.95089912 ; number of evals 10561600 ; total runtime 1126.95412207
# Finished step  51  with cost  5705.95089912 ; number of evals 10776500 ; total runtime 1164.07174015
# Finished step  52  with cost  5705.95089912 ; number of evals 10991700 ; total runtime 1201.70981717
# Finished step  53  with cost  5705.95089912 ; number of evals 11207200 ; total runtime 1240.55420208
# Finished step  54  with cost  5705.95089912 ; number of evals 11423000 ; total runtime 1280.51042509
# Finished step  55  with cost  5705.95089912 ; number of evals 11639100 ; total runtime 1320.63498521
# Finished step  56  with cost  5705.95089912 ; number of evals 11855500 ; total runtime 1361.31370211
# Finished step  57  with cost  5705.95089912 ; number of evals 12072200 ; total runtime 1403.11106014
# Finished step  58  with cost  5705.95089912 ; number of evals 12289200 ; total runtime 1445.00486302
# Finished step  59  with cost  5706.59398362 ; number of evals 12506500 ; total runtime 1487.44887209
#
# Greedy Merge gives cost =  5914.44195443
# Size of S is  86

# %%
# compute the value ratios and runtime ratios for replacement greedy, greedy sum, greedy merge and the random set
otherUsers = random.sample([x for x in range(numUsers/2, numUsers)], 20)

# compute the runtime for greedyMerge
gmTime = time.time()
val = 0
for other in otherUsers:
    val = val + greedyOuter(other, movieName.keys())
gmTime = time.time() - gmTime
print 'Running greedy merge on the ground set takes', gmTime, 'and returns', val, '\n'

ratioRG = []
runtimeRatioRG = []
for S in rgSs:
    mean, ci, rt = computeRatio(S, otherUsers)
    ratioRG.append((mean, ci))
    runtimeRatioRG.append(rt / gmTime)
print 'Done for replacement greedy\n'
    
ratioGS = []
runtimeRatioGS = []
for S in gsSs:
    mean, ci, rt = computeRatio(S, otherUsers)
    ratioGS.append((mean, ci))
    runtimeRatioGS.append(rt / gmTime)
print 'Done for greedy sum\n'

ratioGM = []
runtimeRatioGM = []
for times in range(len(rgSs)):
    ratioGM.append((1, (1,1)))
    runtimeRatioGM.append(1)
#     mean, ci, rt = computeRatio(movieName.keys(), otherUsers)
#     ratioGM.append((mean, ci))
#     runtimeRatioGM.append(rt / gmTime)
print 'Done for greedy merge\n'

ratioRand = []
runtimeRatioRand = []
for times in range(len(rgSs)):
    mean, ci, rt = computeRatio(randS[:(times+k)], otherUsers)
    ratioRand.append((mean, ci))
    runtimeRatioRand.append(rt / gmTime)
print 'Done for random set\n'
# Out:
# Running greedy merge on the ground set takes 3.62574791908 and returns 1217.32989121
#
# 0.912260370442
# 0.943476230887
# 0.945045192416
# 0.94637036482
# 0.951307004906
# 0.952890441697
# 0.959209889743
# 0.964005030554
# 0.964005030554
# 0.965763995308
# 0.968431142628
# 0.971452282062
# 0.971452282062
# 0.973300481565
# 0.973300481565
# 0.976525965967
# 0.977432878648
# 0.981598810803
# 0.981598810803
# 0.982892899942
# 0.984390191752
# 0.987901154443
# 0.991386103849
# 0.991386103849
# 0.991386103849
# 0.990131204049
# 0.992905555285
# 0.994548495309
# 0.994548495309
# 0.994548495309
# 0.994548495309
# 0.994548495309
# 0.99526733558
# 0.99526733558
# 0.99526733558
# 0.99526733558
# 0.99526733558
# 0.99526733558
# 0.99526733558
# 0.997731745616
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 0.997939790349
# 1.00040420038
# 1.00040420038
# 1.00040420038
# 1.00040420038
# 1.00060326974
# 1.00060326974
# 1.00060326974
# Done for replacement greedy
#
# 0.912260370442
# 0.926828201057
# 0.937370718522
# 0.942321480898
# 0.942321480898
# 0.948784627071
# 0.948784627071
# 0.959730722984
# 0.957420415241
# 0.957420415241
# 0.957420415241
# 0.957420415241
# 0.959068146534
# 0.959068146534
# 0.959068146534
# 0.964395607236
# 0.966860017271
# 0.967681487283
# 0.967681487283
# 0.967681487283
# 0.967681487283
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.97096736733
# 0.975418745593
# 0.975418745593
# 0.975418745593
# 0.977061685616
# 0.977061685616
# 0.977061685616
# 0.977061685616
# 0.977061685616
# 0.977061685616
# 0.977061685616
# 0.977061685616
# 0.978267286258
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# 0.978475330991
# Done for greedy sum
#
# Done for greedy merge
#
# 0.352333448756
# 0.381317381542
# 0.381317381542
# 0.382446293748
# 0.519164423337
# 0.567536632383
# 0.567536632383
# 0.584694186494
# 0.584694186494
# 0.584694186494
# 0.584694186494
# 0.586796257022
# 0.586796257022
# 0.59165975103
# 0.59165975103
# 0.59165975103
# 0.59165975103
# 0.59165975103
# 0.59165975103
# 0.59165975103
# 0.59165975103
# 0.594445093935
# 0.63807750439
# 0.63807750439
# 0.639994115727
# 0.639994115727
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.642917441812
# 0.676333704762
# 0.711258874043
# 0.711258874043
# 0.711258874043
# 0.752470516983
# 0.752470516983
# 0.752470516983
# 0.752470516983
# 0.752470516983
# 0.761567622101
# 0.761567622101
# 0.761567622101
# 0.761567622101
# 0.761567622101
# 0.761567622101
# 0.761974687858
# 0.761974687858
# 0.761974687858
# 0.761974687858
# 0.761974687858
# 0.761974687858
# 0.761974687858
# Done for random set

# %%
plt.clf()

ax = plt.subplot(111)

fs = 17

# http://matplotlib.org/users/text_intro.html
ax.set_xlabel('l', fontsize=fs)
ax.set_ylabel('Ratio', fontsize=fs)

plt.ylim(0.1,1.05)
plt.xlim(k, l)

xticks = [k]
for i in range(10, l + 10, 10):
    xticks.append(i)

ax.set_xticks(xticks)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(fs) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(fs) 

colors = ['r', 'b', 'g', 'y']
labelNames = ['Replacement Greedy', 'Greedy Sum', 'Greedy Merge', 'Random Selection']

for ind in range(len(colors)-1, -1,-1):
    ratios = [ratioRG, ratioGS, ratioGM, ratioRand][ind]
    
    vals = []
    for i in range(len(ratios)):
        vals.append(ratios[i][0])
        
    errTop = []
    errBot = []
    for i in range(len(ratios)):
        errBot.append(vals[i] - ratios[i][1][0])
        errTop.append(ratios[i][1][1] - vals[i])
        
    plt.plot([i for i in range(k,l+1)], vals, c = colors[ind][0], linewidth=2, label = labelNames[ind])
    
    if labelNames[ind] != 'Greedy Merge':
        plt.errorbar([i for i in range(k,l+1)], vals, yerr = [errBot, errTop], fmt = colors[ind])
    
# http://matplotlib.org/1.3.0/examples/pylab_examples/legend_demo.html
legend = ax.legend(loc='lower right')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize(fs)

# plt.show()
plt.savefig("../../writeup/images/movielens-sublinear-exp2-ratio")

plt.close()

# %%
for curL in [7,27,57]:
    """
    ========
    Barchart
    ========

    A bar plot with errorbars and height labels on individual bars
    """
    import numpy as np
    import matplotlib.pyplot as plt

    fs = 17
    lfs = 15

    N = 4

    means = (1.0, ratioRG[curL][0], ratioGS[curL][0], ratioRand[curL][0])
    runtimes = (1.0, runtimeRatioRG[curL], runtimeRatioGS[curL], runtimeRatioRand[curL])

    ind = np.arange(N)  # the x locations for the groups
    width = 0.3       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, means, width, color='r')
    rects2 = ax.bar(ind + width, runtimes, width, color='y')

    # add some text for labels, title and axes ticks
    ax.set_ylabel('Performance', fontsize = lfs)
    # ax.set_title('Scores by group and gender')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(('Greedy\nMerge', 'Replacement\nGreedy', 'Greedy\nSum', 'Random'), fontsize = lfs)
    #                    rotation='vertical')

    ax.legend((rects1[0], rects2[0]), ('Objective Value', 'Runtime'))

    plt.ylim(0,1.3)

    def autolabel(rects):
        """
        Attach a text label above each bar displaying its height
        """

        for rect in rects:
            height = rect.get_height()
            if rect != rects[0] > 0:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '~%.f%%   ' % (100 * height),
                        ha='center', va='bottom')
            else:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '  %.f%%' % (100 * height),
                        ha='center', va='bottom')

    def autolabel2(rects):
        """
        Attach a text label above each bar displaying its height
        """
        for rect in rects:
            height = rect.get_height()
            if rect != rects[0] > 0:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '~%.f%%' % (100 * height),
                        ha='left', va='bottom')
            else:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '%.f%%' % (100 * height),
                        ha='left', va='bottom')

    autolabel(rects1)
    autolabel2(rects2)

    # plt.show()

    plt.savefig("../../writeup/images/movielens-sublinear-exp2-barplot-" + str(curL + k))

# %%
for curL in [7,27,57]:
    """
    ========
    Barchart
    ========

    A bar plot with errorbars and height labels on individual bars
    """
    import numpy as np
    import matplotlib.pyplot as plt

    fs = 17
    lfs = 15

    N = 4

    eps = 0.005
    means = (max(1 - ratioRG[curL][0], eps), 1 - ratioGS[curL][0], 1 - ratioRand[curL][0], eps)
    runtimes = (max(runtimeRatioRG[curL], eps), runtimeRatioGS[curL], runtimeRatioRand[curL], 1.0)
    
    print means
    
    ind = np.arange(N)  # the x locations for the groups
    width = 0.3       # the width of the bars

    fig, ax = plt.subplots()
    rects1 = ax.bar(ind, means, width, color='r')
    rects2 = ax.bar(ind + width, runtimes, width, color='y')

    # add some text for labels, title and axes ticks
    ax.set_ylabel('Performance', fontsize = lfs)
    # ax.set_title('Scores by group and gender')
    ax.set_xticks(ind + width / 2)
    ax.set_xticklabels(('Replacement\nGreedy', 'Greedy\nSum', 'Random', 'Greedy\nMerge'), fontsize = lfs)
    #                    rotation='vertical')

    ax.legend((rects1[0], rects2[0]), ('Loss', 'Runtime'), loc='upper left')

    plt.ylim(0,1.2)

    def autolabel(rects):
        """
        Attach a text label above each bar displaying its height
        """

        for rect in rects:
            height = rect.get_height()
            if rect != rects[0] > 0:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '~%.f%%   ' % (100 * height),
                        ha='center', va='bottom')
            else:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '  %.f%%' % (100 * height),
                        ha='center', va='bottom')

    def autolabel2(rects):
        """
        Attach a text label above each bar displaying its height
        """
        for rect in rects:
            height = rect.get_height()
            if rect != rects[0] > 0:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '~%.f%%' % (100 * height),
                        ha='left', va='bottom')
            else:
                ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                        '%.f%%' % (100 * height),
                        ha='left', va='bottom')

    autolabel(rects1)
    autolabel2(rects2)

    # plt.show()

    plt.savefig("../../writeup/images/movielens-sublinear-exp2-barplot-loss-" + str(curL + k))
# Out:
# (0.035994969446008218, 0.040269277016489413, 0.41530581350580065, 0.005)
# (0.0054515046913354848, 0.029032632670152658, 0.3570825581880559, 0.005)
# (0.005, 0.021524669008650021, 0.23802531214219902, 0.005)

# %%
# store locally
filename = open('../data/movielens-exp2.txt', 'w')

def writeInfo(text, values, rt):
    print>>filename, text
    for ind in range(len(values)):
        print>>filename, str(values[ind][0]), str(values[ind][1][0]), str(values[ind][1][1]), str(rt[ind])

writeInfo('RG',ratioRG, runtimeRatioRG)
writeInfo('GS',ratioGS, runtimeRatioGS)
writeInfo('GM',ratioGM, runtimeRatioGM)
writeInfo('Rand',ratioRand, runtimeRatioRand)

# %%
def computeCostOuter2(userIndex, A):
    tot = 0

    curUser = userRatings.keys()[userIndex]

    catA = dict()
    for cat in catID.keys():
        catA[cat] = []
    for mov in A:
        for cat in movieCats[mov]:
            catA[cat].append(mov)

    for cat in catID.keys():
        # now, find the highest rated movie in each category
        highestRated = 0
        for mov in catA[cat]:
            highestRated = max(highestRated, userRatings[curUser][mov])

        tot = tot + highestRated

    return tot

def greedyOuter2(userIndex, S):
    greedyS = []

    use = [False for s in S]

    for times in range(k):
        # at each step, add the element that gives the greatest marginal gain 

        bestInd = -1
        bestCost = -1

        for ind in range(len(S)):
            if use[ind] == False:
                greedyS.append(S[ind])

                curCost = computeCostOuter2(userIndex, greedyS)
                if curCost > bestCost:
                    bestCost = curCost
                    bestInd = ind

                greedyS.pop()

        greedyS.append(S[bestInd])
        use[bestInd] = True

    return greedyS, computeCostOuter2(userIndex, greedyS)

# %%
# find the 3 movies that three users like

usr = otherUsers[0]
print usr
for mov in greedyOuter2(usr, rgSs[57])[0]:
    print movieName[mov]
    
usr = otherUsers[0]
print usr
for mov in greedyOuter2(usr, gsSs[57])[0]:
    print movieName[mov]
    
usr = otherUsers[0]
print usr
for mov in greedyOuter2(usr, randS)[0]:
    print movieName[mov]
# Out:
#  171
# Inception (2010)
# "Monsters, Inc. (2001)"
# Waltz with Bashir (Vals im Bashir) (2008)
# 171
# Inception (2010)
# Shrek (2001)
# Night and Fog (Nuit et brouillard) (1955)
# 171
# "Princess Bride, The (1987)"
# Drive (2011)
# Anvil! The Story of Anvil (2008)
# 60 60
