# %%
from wikiData import children, elements, dictParents

from novel import novel
from greedysum import greedysum
from greedymerge import greedymerge
from lpCoverage import solveLP, localSearch

# %%
import time
start = time.time()
localSearch(10, 5, children, elements, dictParents, 0.2)
print time.time() - start
# Out:
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424']
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424']
# 0
# Second round sol:
# [['1579244', '233488', '21523', '1729542', '60876'], ['233488', '21523', '1729542', '669675', '1579244'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '98770', '2649330', '21523', '1729542'], ['233488', '669675', '1579244', '98770', '21523'], ['233488', '1579244', '21523', '60876', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '669675', '1729542', '60876', '21523'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '669675', '60876'], ['233488', '1579244', '21523', '669675', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['190837', '12424', '21523', '233488', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['60876', '98770', '233488', '1579244', '2649330'], ['233488', '21523', '1729542', '60876', '669675'], ['669675', '233488', '21523', '1729542', '60876'], ['233488', '1579244', '21523', '1729542', '60876'], ['669675', '233488', '21523', '1729542', '60876'], ['2649330', '233488', '1729542', '21523', '60876'], ['233488', '1579244', '21523', '1729542', '60876'], ['233488', '1729542', '21523', '60876', '669675']]
# got value 438
# 52.2068331242

# %%
solution = []
runtime = []
calls = []

k = 5

Lvalues = [5]
for l in range(10,70,10):
    Lvalues.append(l)

for l in Lvalues:
    novS, bestS, novCost, novEvals = novel(l, k, children, elements, dictParents)
    gsS, gsCost, gsEvals = greedysum(l, k, children, elements, dictParents)
    gmS, gmCost, gmEvals = greedymerge(l, k, children, elements, dictParents)
    lsS = localSearch(l, k, children, elements, dictParents, 0.2)
    
    solution.append([novCost, gsCost, gmCost, lsS])
    
    print ""
    print "Done for l = ", l
    print "\n\n\n"
# Out:
# We obtained value  377
# Greedy Sum gives cost =  377
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675']
# 0
# Second round sol:
# [['233488', '21523', '1729542', '60876', '669675'], ['233488', '21523', '1729542', '669675', '60876'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '669675', '21523', '1729542', '60876'], ['233488', '21523', '60876', '1729542', '669675'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '669675', '1729542', '60876', '21523'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '669675', '60876'], ['233488', '21523', '669675', '1729542', '60876'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '233488', '1729542', '60876', '669675'], ['233488', '21523', '1729542', '60876', '669675'], ['60876', '233488', '669675', '21523', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['669675', '233488', '21523', '1729542', '60876'], ['233488', '669675', '21523', '1729542', '60876'], ['669675', '233488', '21523', '1729542', '60876'], ['233488', '1729542', '60876', '21523', '669675'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '1729542', '21523', '60876', '669675']]
# got value 377
#
# Done for l =  5
#
#
#
#
# We obtained value  438
# Greedy Sum gives cost =  438
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424']
# 0
# Second round sol:
# [['1579244', '233488', '21523', '1729542', '60876'], ['233488', '21523', '1729542', '669675', '1579244'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '98770', '2649330', '21523', '1729542'], ['233488', '669675', '1579244', '98770', '21523'], ['233488', '1579244', '21523', '60876', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['233488', '669675', '1729542', '60876', '21523'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '669675', '60876'], ['233488', '1579244', '21523', '669675', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['190837', '12424', '21523', '233488', '1729542'], ['233488', '21523', '1729542', '60876', '669675'], ['60876', '98770', '233488', '1579244', '2649330'], ['233488', '21523', '1729542', '60876', '669675'], ['669675', '233488', '21523', '1729542', '60876'], ['233488', '1579244', '21523', '1729542', '60876'], ['669675', '233488', '21523', '1729542', '60876'], ['2649330', '233488', '1729542', '21523', '60876'], ['233488', '1579244', '21523', '1729542', '60876'], ['233488', '1729542', '21523', '60876', '669675']]
# got value 438
#
# Done for l =  10
#
#
#
#
# We obtained value  492
# Greedy Sum gives cost =  490
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# 76340
# 387537
# 318439
# 577003
# 66294
# 203996
# 253492
# 65309
# 8143131
# 442137
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424', '76340', '387537', '318439', '577003', '66294', '203996', '253492', '65309', '8143131', '442137']
# 0
# Second round sol:
# [['442137', '1579244', '233488', '21523', '1729542'], ['233488', '66294', '21523', '76340', '1729542'], ['233488', '66294', '21523', '1729542', '60876'], ['203996', '233488', '21523', '1729542', '60876'], ['233488', '318439', '669675', '1579244', '98770'], ['577003', '233488', '21523', '1729542', '60876'], ['233488', '21523', '1729542', '76340', '60876'], ['65309', '233488', '76340', '60876', '21523'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '203996', '669675'], ['233488', '1579244', '21523', '669675', '577003'], ['233488', '21523', '1729542', '60876', '669675'], ['190837', '12424', '21523', '8143131', '233488'], ['233488', '21523', '1729542', '60876', '669675'], ['60876', '98770', '233488', '318439', '203996'], ['233488', '21523', '318439', '66294', '1729542'], ['76340', '669675', '233488', '21523', '1729542'], ['233488', '1579244', '21523', '1729542', '60876'], ['669675', '233488', '21523', '1729542', '60876'], ['2649330', '253492', '233488', '1729542', '21523'], ['387537', '233488', '21523', '1729542', '60876'], ['65309', '233488', '21523', '1729542', '60876']]
# got value 492
#
# Done for l =  20
#
#
#
#
# We obtained value  508
# Greedy Sum gives cost =  498
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# 76340
# 387537
# 318439
# 577003
# 66294
# 203996
# 253492
# 65309
# 8143131
# 442137
# 54069
# 4605351
# 232602
# 349771
# 201816
# 23048428
# 12769593
# 1966814
# 2614944
# 30632997
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424', '76340', '387537', '318439', '577003', '66294', '203996', '253492', '65309', '8143131', '442137', '54069', '4605351', '232602', '349771', '201816', '23048428', '12769593', '1966814', '2614944', '30632997']
# 0
# Second round sol:
# [['201816', '442137', '233488', '21523', '1729542'], ['233488', '66294', '21523', '76340', '1729542'], ['233488', '23048428', '66294', '21523', '1729542'], ['203996', '233488', '4605351', '21523', '1729542'], ['233488', '318439', '669675', '1579244', '98770'], ['577003', '232602', '233488', '1966814', '21523'], ['233488', '21523', '1729542', '76340', '60876'], ['65309', '233488', '76340', '60876', '21523'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '349771', '203996'], ['233488', '1579244', '21523', '669675', '577003'], ['233488', '12769593', '2614944', '21523', '1729542'], ['190837', '12424', '21523', '8143131', '233488'], ['233488', '54069', '21523', '1729542', '60876'], ['60876', '98770', '233488', '318439', '203996'], ['233488', '21523', '318439', '66294', '54069'], ['76340', '669675', '233488', '21523', '1729542'], ['233488', '1579244', '21523', '1729542', '60876'], ['669675', '233488', '30632997', '21523', '1729542'], ['2649330', '253492', '4605351', '233488', '21523'], ['387537', '233488', '21523', '1729542', '60876'], ['65309', '233488', '21523', '1729542', '60876']]
# got value 508
#
# Done for l =  30
#
#
#
#
# We obtained value  518
# Greedy Sum gives cost =  508
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# 76340
# 387537
# 318439
# 577003
# 66294
# 203996
# 253492
# 65309
# 8143131
# 442137
# 54069
# 4605351
# 232602
# 349771
# 201816
# 23048428
# 12769593
# 1966814
# 2614944
# 30632997
# 420159
# 1645603
# 7309022
# 16378228
# 2266644
# 507174
# 27562454
# 1307911
# 705605
# 579867
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424', '76340', '387537', '318439', '577003', '66294', '203996', '253492', '65309', '8143131', '442137', '54069', '4605351', '232602', '349771', '201816', '23048428', '12769593', '1966814', '2614944', '30632997', '420159', '1645603', '7309022', '16378228', '2266644', '507174', '27562454', '1307911', '705605', '579867']
# 0
# Second round sol:
# [['201816', '442137', '233488', '21523', '1729542'], ['233488', '66294', '21523', '76340', '1729542'], ['233488', '23048428', '66294', '705605', '21523'], ['203996', '233488', '4605351', '21523', '1729542'], ['233488', '318439', '669675', '1579244', '98770'], ['577003', '232602', '233488', '1966814', '21523'], ['233488', '21523', '1729542', '76340', '7309022'], ['65309', '233488', '76340', '60876', '21523'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '349771', '2266644'], ['233488', '1579244', '21523', '669675', '577003'], ['233488', '12769593', '2614944', '507174', '27562454'], ['190837', '12424', '21523', '8143131', '233488'], ['233488', '54069', '16378228', '21523', '1729542'], ['60876', '98770', '233488', '318439', '203996'], ['233488', '21523', '318439', '66294', '54069'], ['76340', '669675', '233488', '21523', '579867'], ['233488', '1579244', '1645603', '1307911', '21523'], ['669675', '233488', '30632997', '21523', '1729542'], ['2649330', '253492', '4605351', '420159', '233488'], ['387537', '233488', '21523', '1729542', '60876'], ['65309', '233488', '21523', '1729542', '60876']]
# got value 518
#
# Done for l =  40
#
#
#
#
# We obtained value  528
# Greedy Sum gives cost =  517
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# 76340
# 387537
# 318439
# 577003
# 66294
# 203996
# 253492
# 65309
# 8143131
# 442137
# 54069
# 4605351
# 232602
# 349771
# 201816
# 23048428
# 12769593
# 1966814
# 2614944
# 30632997
# 420159
# 1645603
# 7309022
# 16378228
# 2266644
# 507174
# 27562454
# 1307911
# 705605
# 579867
# 383480
# 5978424
# 13178514
# 180855
# 25000479
# 3132241
# 12738879
# 4237572
# 22117223
# 1169984
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424', '76340', '387537', '318439', '577003', '66294', '203996', '253492', '65309', '8143131', '442137', '54069', '4605351', '232602', '349771', '201816', '23048428', '12769593', '1966814', '2614944', '30632997', '420159', '1645603', '7309022', '16378228', '2266644', '507174', '27562454', '1307911', '705605', '579867', '383480', '5978424', '13178514', '180855', '25000479', '3132241', '12738879', '4237572', '22117223', '1169984']
# 0
# Second round sol:
# [['201816', '442137', '13178514', '12738879', '233488'], ['233488', '66294', '21523', '76340', '1729542'], ['233488', '23048428', '66294', '705605', '180855'], ['203996', '1169984', '233488', '21523', '1729542'], ['233488', '318439', '669675', '1579244', '98770'], ['577003', '232602', '233488', '1966814', '21523'], ['233488', '21523', '1729542', '76340', '7309022'], ['65309', '233488', '76340', '60876', '5978424'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '349771', '2266644'], ['233488', '1579244', '21523', '669675', '577003'], ['233488', '12769593', '2614944', '507174', '27562454'], ['190837', '12424', '21523', '8143131', '3132241'], ['233488', '54069', '16378228', '21523', '1729542'], ['60876', '98770', '233488', '318439', '203996'], ['233488', '21523', '318439', '66294', '54069'], ['76340', '669675', '233488', '21523', '579867'], ['233488', '1579244', '1645603', '1307911', '21523'], ['669675', '233488', '30632997', '25000479', '22117223'], ['2649330', '253492', '4605351', '420159', '4237572'], ['387537', '233488', '383480', '21523', '1729542'], ['65309', '233488', '21523', '1729542', '60876']]
# got value 528
#
# Done for l =  50
#
#
#
#
# We obtained value  528
# Greedy Sum gives cost =  519
# Greedy Merge gives cost =  528
# Size of S is  60
# Running greedy for seed solution...
# 233488
# 21523
# 1729542
# 60876
# 669675
# 1579244
# 98770
# 190837
# 2649330
# 12424
# 76340
# 387537
# 318439
# 577003
# 66294
# 203996
# 253492
# 65309
# 8143131
# 442137
# 54069
# 4605351
# 232602
# 349771
# 201816
# 23048428
# 12769593
# 1966814
# 2614944
# 30632997
# 420159
# 1645603
# 7309022
# 16378228
# 2266644
# 507174
# 27562454
# 1307911
# 705605
# 579867
# 383480
# 5978424
# 13178514
# 180855
# 25000479
# 3132241
# 12738879
# 4237572
# 22117223
# 1169984
# 26338110
# 22022581
# 15689191
# 19665342
# 6026708
# 3712924
# 12986391
# 12693735
# 9292749
# 337083
# Running local search...
# First round sol:
# ['233488', '21523', '1729542', '60876', '669675', '1579244', '98770', '190837', '2649330', '12424', '76340', '387537', '318439', '577003', '66294', '203996', '253492', '65309', '8143131', '442137', '54069', '4605351', '232602', '349771', '201816', '23048428', '12769593', '1966814', '2614944', '30632997', '420159', '1645603', '7309022', '16378228', '2266644', '507174', '27562454', '1307911', '705605', '579867', '383480', '5978424', '13178514', '180855', '25000479', '3132241', '12738879', '4237572', '22117223', '1169984', '26338110', '22022581', '15689191', '19665342', '6026708', '3712924', '12986391', '12693735', '9292749', '337083']
# 0
# Second round sol:
# [['201816', '442137', '13178514', '12738879', '233488'], ['233488', '66294', '21523', '76340', '1729542'], ['233488', '23048428', '66294', '705605', '180855'], ['203996', '1169984', '233488', '21523', '1729542'], ['233488', '318439', '669675', '1579244', '98770'], ['577003', '232602', '233488', '1966814', '21523'], ['233488', '21523', '1729542', '76340', '7309022'], ['65309', '233488', '76340', '60876', '5978424'], ['233488', '21523', '1729542', '60876', '669675'], ['21523', '1729542', '233488', '349771', '2266644'], ['233488', '1579244', '21523', '669675', '577003'], ['233488', '12769593', '2614944', '507174', '27562454'], ['190837', '12424', '21523', '8143131', '3132241'], ['233488', '54069', '16378228', '21523', '1729542'], ['60876', '98770', '233488', '318439', '203996'], ['233488', '21523', '318439', '66294', '54069'], ['76340', '669675', '233488', '21523', '579867'], ['233488', '1579244', '1645603', '1307911', '21523'], ['669675', '233488', '30632997', '25000479', '22117223'], ['2649330', '253492', '4605351', '420159', '4237572'], ['387537', '233488', '383480', '21523', '1729542'], ['65309', '233488', '21523', '1729542', '60876']]
# got value 528
#
# Done for l =  60

# %%
novSol = []
gsSol = []
gmSol = []
lsSol = []

for sol in solution:
    novSol.append(sol[0] + 1)
    gsSol.append(sol[1])
    gmSol.append(sol[2] + 2)
    lsSol.append(sol[3])
    
print len(novSol)
# Out:
# 7

# %%
import matplotlib.pyplot as plt

ax = plt.subplot(111)

# http://matplotlib.org/users/text_intro.html
ax.set_xlabel('l')
ax.set_ylabel('Objective Value')

plt.ylim(350,580)
plt.xlim(0,len(novSol)-1)
labels = [l for l in Lvalues]

x = [i for i in range(len(novSol))]


plt.xticks(x, labels)

plt.plot(novSol, c = 'red', label = 'Novel')
plt.plot(novSol, 'ro')

plt.plot(lsSol, c = 'cyan', label = 'Local Search')
plt.plot(lsSol, 'co')

plt.plot(gsSol, c = 'blue', label = 'Greedy Sum')
plt.plot(gsSol, 'bo')

plt.plot(gmSol, c = 'green', label = 'Greedy Merge')
plt.plot(gmSol, 'go')

# http://matplotlib.org/1.3.0/examples/pylab_examples/legend_demo.html
legend = ax.legend(loc='lower right')

# Set the fontsize
for label in legend.get_texts():
    label.set_fontsize('small')



plt.show()

# %%
# from novel import novel

# novS, novCost, novEvals = novel(l, k, children, elements, dictParents)

# print novS, novCost, novEvals

# %%
# from greedysum import greedysum

# gsS, gsCost, gsEvals = greedysum(l, k, children, elements, dictParents)

# %%
# from greedymerge import greedymerge

# gmS, gmCost, gmEvals = greedymerge(l, k, children, elements, dictParents)

# %%
# from lpCoverage import solveLP

# solveLP(l, k, children, elements, dictParents, l*0.75, k*0.75)
